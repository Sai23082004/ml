# %%
import numpy as np
from scipy import stats

data = [1,20,6,4,85,96,32,0,4,74,85,66,66,85,74,78]

mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data, keepdims=True)[0][0]

variance = np.var(data)
std_dev = np.std(data)
range_val = max(data) - min(data)

print("\n=== DATA ===")
print(data)

print("\n=== CENTRAL TENDENCY ===")
print("Mean =", mean)
print("Median =", median)
print("Mode =", mode)

print("\n=== DISPERSION ===")
print("Variance =", variance)
print("Standard Deviation =", std_dev)
print("Range =", range_val)
# Out:
# === DATA ===
# [1, 20, 6, 4, 85, 96, 32, 0, 4, 74, 85, 66, 66, 85, 74, 78]
#
# === CENTRAL TENDENCY ===
# Mean = 48.5
# Median = 66.0
# Mode = 85
#
# === DISPERSION ===
# Variance = 1281.0
# Standard Deviation = 35.79106033634656
# Range = 96
